# %%
import json
with open("data/Labels.json", 'r') as f:
  data = json.load(f)

# %%
sorted_data = dict(sorted(data.items()))

# %%
import numpy as np
import os
ditctionary = {}
for i,file in enumerate(os.listdir("data/exercise_data/")):
    np_array = np.load(os.path.join("data/exercise_data/", file))
    ditctionary[i] = np_array
ditctionary
# Out:
# {0: array([[[ 84,  76,  73],
#          [116, 106, 101],
#          [ 93,  90,  78],
#          ...,
#          [215, 204, 152],
#          [199, 176, 120],
#          [179, 158, 105]],
#
#         [[100,  93,  90],
#          [ 79,  73,  68],
#          [ 76,  76,  64],
#          ...,
#          [192, 173, 121],
#          [172, 143,  88],
#          [192, 171, 123]],
#
#         [[ 73,  65,  59],
#          [ 60,  52,  48],
#          [ 70,  70,  58],
#          ...,
#          [212, 188, 158],
#          [193, 168, 119],
#          [209, 192, 134]],
#
#         ...,
#
#         [[ 70,  73,  61],
#          [ 92,  98,  80],
#          [ 82,  73,  61],
#          ...,
#          [107, 103,  62],
#          [ 78,  71,  46],
#          [ 55,  52,  40]],
#
#         [[ 55,  57,  49],
#          [ 86,  94,  75],
#          [ 96,  94,  72],
#          ...,
#          [119, 116,  68],
#          [ 77,  65,  44],
#          [ 54,  43,  38]],
#
#         [[ 58,  54,  48],
# ...

# %%
sorted_data
# Out:
# {'0': 4,
#  '1': 7,
#  '10': 3,
#  '11': 9,
#  '12': 0,
#  '13': 8,
#  '14': 6,
#  '15': 9,
#  '16': 0,
#  '17': 7,
#  '18': 7,
#  '19': 8,
#  '2': 1,
#  '20': 3,
#  '21': 9,
#  '22': 1,
#  '23': 7,
#  '24': 9,
#  '25': 1,
#  '26': 3,
#  '27': 9,
#  '28': 1,
#  '29': 2,
#  '3': 0,
#  '30': 2,
#  '31': 8,
#  '32': 2,
#  '33': 8,
#  '34': 7,
#  '35': 4,
#  '36': 4,
#  '37': 2,
#  '38': 0,
#  '39': 2,
#  '4': 4,
#  '40': 7,
#  '41': 9,
#  '42': 9,
#  '43': 1,
#  '44': 5,
#  '45': 1,
#  '46': 1,
#  '47': 4,
#  '48': 4,
#  '49': 6,
#  '5': 7,
#  '50': 3,
#  '51': 4,
#  '52': 7,
#  '53': 5,
#  '54': 7,
#  '55': 8,
#  '56': 8,
#  '57': 5,
#  '58': 1,
#  '59': 7,
#  '6': 5,
#  '60': 9,
#  '61': 0,
#  '62': 6,
#  '63': 5,
#  '64': 1,
#  '65': 1,
#  '66': 7,
#  '67': 9,
#  '68': 0,
#  '69': 0,
#  '7': 9,
#  '70': 8,
#  '71': 4,
#  '72': 0,
#  '73': 6,
#  '74': 6,
#  '75': 7,
#  '76': 5,
#  '77': 0,
#  '78': 6,
#  '79': 8,
#  '8': 9,
#  '80': 9,
#  '81': 5,
#  '82': 1,
#  '83': 4,
#  '84': 5,
# ...

# %%
import numpy as np
from sklearn.utils import shuffle
arr = np.arange(16).reshape((4, 4))
arr2 = np.arange(16).reshape((4, 4))
X, y = shuffle(arr, arr2)
print(X)
print(y)
# Out:
# [[12 13 14 15]
#  [ 4  5  6  7]
#  [ 0  1  2  3]
#  [ 8  9 10 11]]
# [[12 13 14 15]
#  [ 4  5  6  7]
#  [ 0  1  2  3]
#  [ 8  9 10 11]]

# %%
import numpy as np
arr = np.arange(0,100,1)
b1 = arr[:60]
arr[60:]
np.concatenate((arr[60:],arr[:20]), axis=0).shape
# Out:
# (60,)

# %%
import json
from operator import itemgetter, attrgetter
test_dict = {"0": -1, "1": -2, "2": -3}
with open("test_labels.json", 'r') as file:
            data = json.load(file)
d = {int(k):int(v) for k,v in test_dict.items()}
print(list(dict(sorted(d.items())).values()))
# Out:
# [-1, -2, -3]

# %%
arr = np.arange(0,10,1)
arr.shape
arr.reshape(3,-1).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 3
#       1 arr = np.arange(0,10,1)
#       2 arr.shape
# ----> 3 arr.reshape(3,-1).shape
#
# ValueError: cannot reshape array of size 10 into shape (3,newaxis)

# %%
import matplotlib.pyplot as plt

#define figure
fig = plt.figure()

#add subplots
fig.add_subplot(321).set_title('321')
fig.add_subplot(322).set_title('322')
fig.add_subplot(323).set_title('323')
fig.add_subplot(324).set_title('324')
fig.add_subplot(325).set_title('325')


#display plots
plt.show()

# %%
int(np.ceil(10/3))
# Out:
# 4

# %%
with open("Labels.json", 'r') as file:
            data = json.load(file)
data["5"]

img = np.load("exercise_data/5.npy")
plt.imshow(img)
plt.show()
